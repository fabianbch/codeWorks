# %% [markdown]
# # **Clasificador Bayesiano con Dataset para Predicción de Cáncer de Mama**
#
# Conjunto de datos de Wisconsin (diagnóstico) sobre el cáncer de mama. Link del Dataset en Kaggle:
#
# https://www.kaggle.com/uciml/breast-cancer-wisconsin-data

# %% [markdown]
# # **Preparación del entorno**

# %%
import numpy as np
import pandas as pd

from sklearn.naive_bayes import GaussianNB
from sklearn.model_selection import train_test_split

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # **Lectura y visualización de los datos**
#
# Previamente se debe descargar el dataset del link proporcionado y subirlo a Google Colab.

# %%
data_frame = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/Clasificador Bayesiano/data.csv", header = 0)

# %%
data_frame.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
#    ...  texture_worst  perimeter_worst  area_worst  smoothness_worst  \
# 0  ...          17.33           184.60      2019.0            0.1622
# 1  ...          23.41           158.80      1956.0            0.1238
# 2  ...          25.53           152.50      1709.0            0.1444
# 3  ...          26.50            98.87       567.7            0.2098
# 4  ...          16.67           152.20      1575.0            0.1374
#
#    compactness_worst  concavity_worst  concave points_worst  symmetry_worst  \
# 0             0.6656           0.7119                0.2654          0.4601
# 1             0.1866           0.2416                0.1860          0.2750
# 2             0.4245           0.4504                0.2430          0.3613
# 3             0.8663           0.6869                0.2575          0.6638
# 4             0.2050           0.4000                0.1625          0.2364
#
#    fractal_dimension_worst  Unnamed: 32
# 0                  0.11890          NaN
# 1                  0.08902          NaN
# 2                  0.08758          NaN
# 3                  0.17300          NaN
# 4                  0.07678          NaN
#
# [5 rows x 33 columns]

# %% [markdown]
# # **Selección de las características**

# %% [markdown]
# **Selección de las características que se usará como entradas (X) y la salida esperada (y).**

# %%
X = data_frame[['radius_mean', 'area_mean', 'perimeter_mean', 'concavity_mean', 'concave points_mean']]
y = data_frame['diagnosis']

# %% [markdown]
# **Separación del dataset: 70% entrenamiento (Train), 30% prueba (Test)**

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3)

# %% [markdown]
# **Visualización como quedaron los datasets para entrenamiento y prueba.**

# %%
print(X_train, y_train)
print(X_test, y_test)
# Out:
#      radius_mean  area_mean  perimeter_mean  concavity_mean  \
# 96         12.18      451.1           77.79         0.02490
# 462        14.40      646.1           92.25         0.03476
# 436        12.87      509.2           82.67         0.01797
# 95         20.26     1264.0          132.40         0.14650
# 445        11.99      441.3           77.61         0.05441
# ..           ...        ...             ...             ...
# 345        10.26      321.6           66.20         0.03581
# 344        11.71      420.3           75.03         0.04006
# 34         16.13      807.2          107.00         0.13540
# 184        15.28      710.6           98.92         0.05375
# 159        10.90      366.8           68.69         0.00309
#
#      concave points_mean
# 96              0.029410
# 462             0.017370
# 436             0.020900
# 95              0.086830
# 445             0.042740
# ..                   ...
# 345             0.020370
# 344             0.032500
# 34              0.077520
# 184             0.032630
# 159             0.006588
#
# [398 rows x 5 columns] 96     B
# 462    B
# 436    B
# 95     M
# 445    B
#       ..
# 345    B
# 344    B
# 34     M
# 184    M
# 159    B
# Name: diagnosis, Length: 398, dtype: object
#      radius_mean  area_mean  perimeter_mean  concavity_mean  \
# 531        11.67      416.2           75.21        0.042000
# 83         19.10     1132.0          129.10        0.193700
# 179        12.81      508.8           81.29        0.009193
# 173        11.08      372.7           70.21        0.023630
# 446        17.75      981.6          117.30        0.169800
# ..           ...        ...             ...             ...
# 348        11.47      402.7           73.02        0.025870
# 74         12.31      470.9           79.19        0.033720
# 304        11.46      403.1           73.59        0.033440
# 277        18.81     1102.0          120.90        0.080200
# 322        12.86      504.8           82.82        0.038000
#
#      concave points_mean
# 531              0.02157
# 83               0.14690
# 179              0.01330
# 173              0.02583
# 446              0.08293
# ..                   ...
# 348              0.02322
# 74               0.02272
# 304              0.01502
# 277              0.05843
# 322              0.03400
#
# [171 rows x 5 columns] 531    B
# 83     M
# 179    B
# 173    B
# 446    M
#       ..
# 348    B
# 74     B
# 304    B
# 277    M
# 322    B
# Name: diagnosis, Length: 171, dtype: object

# %% [markdown]
# # **Creación y entrenamiento del Clasificador Bayesiano**

# %%
naive_bayes = GaussianNB().fit(X_train, y_train)

# %% [markdown]
# # **Predección sobre el dataset de entrenamiento y prueba**

# %%
print("Predicciones con datos de entrenamiento")
print(naive_bayes.predict(X_train))
print("Salidas de entrenamiento")
print(y_train.values)
print("Predicciones con datos de prueba")
print(naive_bayes.predict(X_test))
print("Salidas de prueba")
print(y_test.values)
# Out:
# Predicciones con datos de entrenamiento
# ['B' 'B' 'B' 'M' 'B' 'B' 'B' 'B' 'B' 'B' 'M' 'B' 'M' 'B' 'B' 'M' 'M' 'B'
#  'B' 'B' 'M' 'B' 'B' 'B' 'M' 'M' 'B' 'B' 'B' 'B' 'M' 'B' 'M' 'M' 'M' 'B'
#  'M' 'M' 'B' 'B' 'B' 'B' 'M' 'B' 'B' 'B' 'M' 'M' 'B' 'B' 'M' 'B' 'B' 'B'
#  'B' 'M' 'M' 'B' 'B' 'B' 'B' 'B' 'B' 'M' 'B' 'M' 'B' 'B' 'B' 'M' 'B' 'B'
#  'B' 'B' 'M' 'B' 'B' 'B' 'B' 'B' 'M' 'B' 'M' 'M' 'M' 'B' 'B' 'B' 'B' 'M'
#  'B' 'B' 'B' 'M' 'B' 'M' 'M' 'M' 'B' 'M' 'M' 'M' 'B' 'B' 'B' 'M' 'M' 'M'
#  'M' 'B' 'B' 'M' 'B' 'B' 'B' 'B' 'M' 'M' 'M' 'M' 'M' 'B' 'B' 'B' 'B' 'M'
#  'M' 'B' 'B' 'M' 'M' 'B' 'B' 'M' 'M' 'M' 'B' 'B' 'B' 'B' 'B' 'B' 'M' 'B'
#  'B' 'B' 'B' 'B' 'B' 'M' 'M' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'M' 'B' 'M' 'B'
#  'B' 'B' 'M' 'B' 'M' 'B' 'B' 'B' 'M' 'B' 'B' 'B' 'B' 'B' 'M' 'B' 'M' 'M'
#  'B' 'M' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'M' 'B' 'B' 'M' 'M' 'B' 'B'
#  'B' 'B' 'B' 'B' 'B' 'B' 'M' 'M' 'M' 'B' 'M' 'B' 'B' 'B' 'B' 'M' 'M' 'B'
#  'B' 'M' 'B' 'B' 'M' 'M' 'B' 'B' 'B' 'M' 'M' 'B' 'B' 'B' 'M' 'M' 'M' 'B'
#  'B' 'M' 'B' 'B' 'B' 'B' 'M' 'M' 'B' 'M' 'B' 'M' 'B' 'M' 'B' 'B' 'B' 'B'
#  'B' 'M' 'M' 'B' 'B' 'M' 'M' 'M' 'B' 'B' 'M' 'B' 'B' 'B' 'B' 'B' 'B' 'M'
#  'B' 'M' 'M' 'B' 'M' 'M' 'M' 'M' 'B' 'M' 'B' 'M' 'B' 'B' 'B' 'B' 'B' 'M'
#  'B' 'B' 'B' 'B' 'B' 'M' 'B' 'M' 'M' 'M' 'B' 'B' 'M' 'M' 'B' 'B' 'B' 'B'
#  'B' 'B' 'B' 'M' 'B' 'B' 'M' 'B' 'B' 'B' 'B' 'B' 'M' 'B' 'B' 'M' 'M' 'B'
#  'M' 'B' 'B' 'B' 'M' 'B' 'B' 'B' 'M' 'B' 'B' 'M' 'B' 'M' 'B' 'B' 'B' 'M'
#  'B' 'B' 'M' 'M' 'B' 'M' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'M' 'M' 'B' 'M' 'B'
#  'B' 'B' 'M' 'B' 'B' 'M' 'B' 'B' 'B' 'B' 'B' 'M' 'B' 'M' 'M' 'B' 'M' 'B'
#  'B' 'M' 'B' 'B' 'B' 'B' 'B' 'B' 'M' 'B' 'M' 'B' 'B' 'B' 'M' 'B' 'B' 'M'
#  'B' 'B']
# Salidas de entrenamiento
# ['B' 'B' 'B' 'M' 'B' 'B' 'B' 'B' 'B' 'B' 'M' 'M' 'M' 'B' 'B' 'M' 'M' 'B'
#  'B' 'B' 'M' 'B' 'B' 'B' 'M' 'M' 'B' 'B' 'B' 'B' 'B' 'B' 'M' 'B' 'M' 'B'
#  'M' 'M' 'B' 'B' 'B' 'B' 'M' 'B' 'B' 'M' 'M' 'M' 'B' 'B' 'M' 'B' 'B' 'B'
#  'B' 'M' 'M' 'B' 'B' 'B' 'B' 'M' 'M' 'M' 'B' 'M' 'B' 'B' 'B' 'M' 'B' 'B'
#  'B' 'B' 'M' 'B' 'B' 'B' 'B' 'B' 'M' 'B' 'M' 'M' 'B' 'B' 'B' 'M' 'B' 'M'
#  'B' 'B' 'B' 'M' 'B' 'M' 'M' 'M' 'B' 'M' 'M' 'M' 'B' 'B' 'B' 'M' 'M' 'B'
#  'M' 'B' 'B' 'M' 'M' 'B' 'B' 'B' 'M' 'M' 'M' 'M' 'M' 'B' 'B' 'B' 'B' 'M'
#  'M' 'B' 'B' 'M' 'M' 'B' 'B' 'M' 'M' 'M' 'B' 'B' 'B' 'B' 'B' 'B' 'M' 'M'
#  'B' 'M' 'B' 'B' 'B' 'M' 'M' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'M' 'B' 'M' 'M'
#  'B' 'B' 'M' 'B' 'M' 'B' 'B' 'B' 'M' 'B' 'B' 'B' 'B' 'B' 'M' 'B' 'B' 'M'
#  'B' 'M' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'M' 'B' 'B' 'M' 'M' 'B' 'M'
#  'B' 'B' 'B' 'B' 'B' 'B' 'M' 'M' 'M' 'B' 'B' 'B' 'B' 'B' 'B' 'M' 'M' 'B'
#  'B' 'M' 'B' 'B' 'M' 'M' 'B' 'B' 'B' 'M' 'M' 'B' 'B' 'B' 'M' 'M' 'M' 'B'
#  'B' 'M' 'B' 'B' 'B' 'B' 'M' 'M' 'B' 'M' 'B' 'M' 'B' 'M' 'B' 'B' 'B' 'B'
#  'B' 'M' 'M' 'B' 'B' 'M' 'M' 'M' 'B' 'B' 'M' 'B' 'B' 'B' 'B' 'B' 'B' 'M'
#  'B' 'M' 'M' 'B' 'M' 'M' 'M' 'M' 'B' 'M' 'B' 'M' 'B' 'B' 'B' 'B' 'B' 'M'
#  'B' 'B' 'B' 'M' 'M' 'M' 'B' 'M' 'M' 'M' 'B' 'B' 'M' 'M' 'B' 'B' 'B' 'B'
#  'B' 'B' 'B' 'M' 'B' 'B' 'M' 'B' 'B' 'B' 'B' 'M' 'M' 'B' 'B' 'M' 'M' 'B'
#  'M' 'B' 'B' 'B' 'M' 'B' 'B' 'B' 'M' 'B' 'B' 'M' 'B' 'M' 'B' 'B' 'M' 'M'
#  'B' 'B' 'M' 'M' 'B' 'B' 'B' 'B' 'M' 'B' 'B' 'B' 'B' 'M' 'M' 'B' 'M' 'B'
#  'M' 'B' 'M' 'B' 'B' 'M' 'M' 'B' 'B' 'B' 'B' 'M' 'M' 'M' 'M' 'M' 'M' 'B'
#  'B' 'M' 'B' 'B' 'B' 'B' 'B' 'B' 'M' 'B' 'M' 'B' 'B' 'B' 'B' 'B' 'B' 'M'
#  'M' 'B']
# Predicciones con datos de prueba
# ['B' 'M' 'B' 'B' 'M' 'M' 'B' 'B' 'B' 'B' 'B' 'M' 'M' 'B' 'B' 'B' 'B' 'M'
#  'M' 'B' 'B' 'M' 'B' 'B' 'M' 'M' 'B' 'B' 'M' 'B' 'B' 'M' 'B' 'B' 'B' 'B'
#  'B' 'B' 'B' 'M' 'M' 'B' 'B' 'M' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'M' 'B'
#  'M' 'M' 'B' 'B' 'B' 'M' 'B' 'B' 'B' 'B' 'M' 'B' 'B' 'B' 'B' 'B' 'B' 'B'
#  'B' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'M' 'B' 'M' 'B' 'B' 'M' 'B' 'B'
#  'B' 'B' 'B' 'M' 'M' 'B' 'M' 'B' 'B' 'B' 'M' 'B' 'M' 'B' 'B' 'M' 'B' 'B'
#  'B' 'B' 'B' 'M' 'B' 'M' 'B' 'B' 'B' 'B' 'B' 'M' 'M' 'M' 'B' 'B' 'B' 'M'
#  'B' 'M' 'B' 'M' 'M' 'B' 'B' 'M' 'M' 'B' 'M' 'B' 'B' 'M' 'M' 'B' 'M' 'M'
#  'M' 'B' 'M' 'M' 'M' 'M' 'B' 'M' 'B' 'B' 'M' 'M' 'B' 'M' 'M' 'B' 'B' 'B'
#  'M' 'M' 'B' 'B' 'B' 'B' 'B' 'M' 'B']
# Salidas de prueba
# ['B' 'M' 'B' 'B' 'M' 'M' 'B' 'B' 'B' 'B' 'B' 'M' 'M' 'B' 'B' 'M' 'B' 'B'
#  'M' 'M' 'M' 'M' 'B' 'M' 'B' 'M' 'B' 'M' 'M' 'B' 'B' 'M' 'B' 'B' 'B' 'B'
#  'B' 'B' 'B' 'M' 'M' 'B' 'B' 'M' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'M' 'B'
#  'M' 'M' 'B' 'B' 'B' 'M' 'M' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'M' 'B'
#  'B' 'M' 'B' 'B' 'B' 'M' 'B' 'B' 'B' 'B' 'M' 'B' 'M' 'B' 'B' 'M' 'B' 'B'
#  'B' 'B' 'B' 'B' 'M' 'M' 'M' 'B' 'B' 'B' 'M' 'B' 'M' 'B' 'M' 'M' 'B' 'B'
#  'B' 'B' 'B' 'M' 'B' 'M' 'B' 'B' 'M' 'B' 'B' 'M' 'M' 'M' 'M' 'B' 'B' 'M'
#  'B' 'M' 'B' 'M' 'M' 'B' 'B' 'M' 'M' 'B' 'M' 'B' 'B' 'B' 'M' 'B' 'M' 'M'
#  'M' 'B' 'M' 'M' 'M' 'M' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'M' 'B' 'B' 'B' 'B'
#  'M' 'M' 'B' 'B' 'B' 'B' 'B' 'M' 'B']

# %% [markdown]
# # **Medición de la exactitud (Accuracy) con el dataset de entrenamiento y prueba**

# %%
naive_bayes.score(X_train, y_train)
# Out:
# 0.9296482412060302

# %%
naive_bayes.score(X_test, y_test)
# Out:
# 0.8713450292397661
